# %%
from sklearn.datasets import fetch_lfw_people
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.decomposition import PCA

# %%
# 载入数据
lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# %%
plt.imshow(lfw_people.images[5], cmap="gray")
plt.show()

# %%
# 照片的数据格式
n_samples, h, w = lfw_people.images.shape
print("照片个数：", n_samples)
print("照片高度：", h)
print("照片宽度：", w)
print(lfw_people.images.shape)
# Out:
# 照片个数： 1288
# 照片高度： 50
# 照片宽度： 37
# (1288, 50, 37)

# %%
lfw_people.data.shape
# Out:
# (1288, 1850)

# %%
lfw_people.target
# Out:
# array([5, 6, 3, ..., 5, 3, 5], dtype=int64)

# %%
lfw_people.target_names
# Out:
# array(['Ariel Sharon', 'Colin Powell', 'Donald Rumsfeld', 'George W Bush',
#        'Gerhard Schroeder', 'Hugo Chavez', 'Tony Blair'], dtype='<U17')

# %%
lfw_people.target_names.shape
# Out:
# (7,)

# %%
n_classes = lfw_people.target_names.shape[0]

# %%
# 拆分数据集
x_train, x_test, y_train, y_test = train_test_split(lfw_people.data, lfw_people.target)

# %%
# 创建分类器
model = SVC(kernel="rbf", class_weight="balanced")
model.fit(x_train, y_train)
# Out:
# SVC(class_weight='balanced')

# %%
predictions = model.predict(x_test)
print(classification_report(y_test, predictions, target_names=lfw_people.target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.84      0.76      0.80        21
#      Colin Powell       0.76      0.93      0.83        57
#   Donald Rumsfeld       0.84      0.81      0.83        32
#     George W Bush       0.94      0.85      0.89       123
# Gerhard Schroeder       0.59      0.69      0.63        29
#       Hugo Chavez       0.74      0.74      0.74        23
#        Tony Blair       0.82      0.76      0.79        37
#
#          accuracy                           0.82       322
#         macro avg       0.79      0.79      0.79       322
#      weighted avg       0.83      0.82      0.82       322

# %% [markdown]
# # PCA降维           减小计算复杂度，去除噪声数据

# %%
# 100个维度 ，原维度1850
n_components = 100
pca = PCA(n_components=n_components, whiten=True).fit(lfw_people.data)
x_train_pca = pca.transform(x_train)
x_test_pca = pca.transform(x_test)

# %%
x_train_pca.shape
# Out:
# (966, 100)

# %%
model = SVC(kernel="rbf", class_weight="balanced")
model.fit(x_train_pca, y_train)
# Out:
# SVC(class_weight='balanced')

# %%
predictions = model.predict(x_test_pca)
print(classification_report(y_test, predictions, target_names=lfw_people.target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.89      0.76      0.82        21
#      Colin Powell       0.73      0.91      0.81        57
#   Donald Rumsfeld       0.85      0.88      0.86        32
#     George W Bush       0.88      0.91      0.90       123
# Gerhard Schroeder       0.81      0.76      0.79        29
#       Hugo Chavez       1.00      0.74      0.85        23
#        Tony Blair       0.90      0.70      0.79        37
#
#          accuracy                           0.85       322
#         macro avg       0.87      0.81      0.83       322
#      weighted avg       0.86      0.85      0.85       322

# %% [markdown]
# # 调参

# %%
param_grid = {'C': [0.1, 1, 5, 10, 100],
             'gamma': [0.0005, 0.001, 0.005, 0.01]}
model = GridSearchCV(SVC(kernel="rbf", class_weight="balanced"), param_grid=param_grid)
model.fit(x_train_pca, y_train)
print(model.best_estimator_)
# Out:
# SVC(C=100, class_weight='balanced', gamma=0.005)

# %%
predictions = model.predict(x_test_pca)
print(classification_report(y_test, predictions, target_names=lfw_people.target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.82      0.67      0.74        21
#      Colin Powell       0.79      0.91      0.85        57
#   Donald Rumsfeld       0.79      0.81      0.80        32
#     George W Bush       0.86      0.93      0.89       123
# Gerhard Schroeder       0.91      0.69      0.78        29
#       Hugo Chavez       0.95      0.78      0.86        23
#        Tony Blair       0.85      0.76      0.80        37
#
#          accuracy                           0.84       322
#         macro avg       0.85      0.79      0.82       322
#      weighted avg       0.85      0.84      0.84       322

# %%
param_grid = {'C': [0.6, 1, 2, 2.7, 2.8, 3],
             'gamma': [0.003, 0.004, 0.005, 0.006, 0.007]}
model = GridSearchCV(SVC(kernel="rbf", class_weight="balanced"), param_grid=param_grid)
model.fit(x_train_pca, y_train)
print(model.best_estimator_)
# Out:
# SVC(C=2.8, class_weight='balanced', gamma=0.005)

# %%
predictions = model.predict(x_test_pca)
print(classification_report(y_test, predictions, target_names=lfw_people.target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.83      0.71      0.77        21
#      Colin Powell       0.82      0.93      0.87        57
#   Donald Rumsfeld       0.76      0.88      0.81        32
#     George W Bush       0.92      0.94      0.93       123
# Gerhard Schroeder       0.88      0.72      0.79        29
#       Hugo Chavez       1.00      0.78      0.88        23
#        Tony Blair       0.85      0.78      0.82        37
#
#          accuracy                           0.87       322
#         macro avg       0.86      0.82      0.84       322
#      weighted avg       0.87      0.87      0.87       322

# %% [markdown]
# # 画图

# %%
def plot_gallery(images, titles, h, w, n_row=3, n_col=5):
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())
        
# 获取一张图片title
def title(predictions, y_test, target_names, i):
    pred_name = target_names[predictions[i]].split(" ")[-1]
    true_name = target_names[y_test[i]].split(" ")[-1]
    return "predicted: %s\ntrue:    %s" % (pred_name, true_name)
# 获取所有图片title
prediction_titles = [title(predictions, y_test, lfw_people.target_names, i) for i in range(len(predictions))]

# 画图
plot_gallery(x_test, prediction_titles, h, w)

# plt.show()

# %% [markdown]
# 数据集地址：http://vis-www.cs.umass.edu/lfw/
